# %% [markdown]
# ## Python Mini-Project: Data Clean-Up, Pt. 2
#
# Pay close attention to the prompts to help guide you through this task.

# %%
# Dependencies
import pandas as pd

# %%
# load CSV
file = "Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types
# You may need to encode this file
survey_df = pd.read_csv(file, encoding = 'iso-8859-1', low_memory=False)
survey_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# ...

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111
# Consider using iloc
extract_df = survey_df.iloc[:, [0, 1, 2, 3, 4, 6, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
extract_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# 0                NaN          NaN                 NaN                NaN
# 1                NaN          NaN                 NaN                NaN
# 2                NaN          NaN                 NaN                NaN
# 3                NaN          NaN                 NaN                NaN
# 4                NaN          NaN                 NaN                NaN
#
#    ChildrenNumber                 CityPopulation  ...  \
# 0             NaN  between 100,000 and 1 million  ...
# ...

# %%
# Change reading 0 and 1 to No and Yes, respectively
extract_df = extract_df.replace({0:"No", 1:"Yes"})
extract_df.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo BootcampName  BootcampPostSalary BootcampRecommend  \
# 0               NaN          NaN                 NaN               NaN
# 1               NaN          NaN                 NaN               NaN
# 2               NaN          NaN                 NaN               NaN
# 3               NaN          NaN                 NaN               NaN
# 4               NaN          NaN                 NaN               NaN
#
#   ChildrenNumber                 CityPopulation  ...  \
# 0            NaN  between 100,000 and 1 million  ...
# 1            NaN  between 100,000 and 1 million  ...
# ...

# %%
# Extract rows for only those who attended a bootcamp
attended_df = extract_df.loc[extract_df["AttendedBootcamp"] == "Yes"]
attended_df.head()
# Out:
#       Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93   32.0              Yes            Yes                   No
# 97   26.0              Yes            Yes                  Yes
# 130  41.0              Yes            Yes                  Yes
# 159  26.0              Yes            Yes                   No
# 188  24.0              Yes             No                  NaN
#
#     BootcampLoanYesNo      BootcampName  BootcampPostSalary BootcampRecommend  \
# 93                 No    Codify Academy                 NaN                No
# 97                 No    DaVinci Coders             45000.0                No
# 130               Yes     Coder Foundry             75000.0               Yes
# 159                No  General Assembly                 NaN                No
# 188               Yes               NaN                 NaN                No
#
#     ChildrenNumber                 CityPopulation  ...  \
# 93             NaN  between 100,000 and 1 million  ...
# ...

# %%
# Create DataFrame of the various boot camps along with the number of participants (enrollees)
# Create a DataFrame from using value_counts
bc_name = attended_df["BootcampName"].value_counts()
#bc_name_df = pd.DataFrame(bc_name)
bc_name = bc_name.reset_index()
bc_name.columns = ["BootcampName","Count"]
bc_name.head()
# Out:
#             BootcampName  Count
# 0       General Assembly     90
# 1        Flatiron School     54
# 2           Dev Bootcamp     48
# 3          The Iron Yard     40
# 4  Prime Digital Academy     30

# %%
# Replace 'No' and 'Yes' with '0' and '1' respectively
convert_to_num = attended_df.replace({"No":0, "Yes":1})
convert_to_num.head()
# Out:
#       Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 93   32.0                 1             1.0                   0.0
# 97   26.0                 1             1.0                   1.0
# 130  41.0                 1             1.0                   1.0
# 159  26.0                 1             1.0                   0.0
# 188  24.0                 1             0.0                   NaN
#
#      BootcampLoanYesNo      BootcampName  BootcampPostSalary  \
# 93                 0.0    Codify Academy                 NaN
# 97                 0.0    DaVinci Coders             45000.0
# 130                1.0     Coder Foundry             75000.0
# 159                0.0  General Assembly                 NaN
# 188                1.0               NaN                 NaN
#
#      BootcampRecommend  ChildrenNumber                 CityPopulation  ...  \
# 93                 0.0             NaN  between 100,000 and 1 million  ...
# ...

# %%
# Group by cols -- Name, Recommend
groupby_name = convert_to_num.groupby("BootcampName")
groupby_name.sum().head()
# Out:
#                          Age  AttendedBootcamp  BootcampFinish  \
# BootcampName
# 10x.org.il             144.0                 5             2.0
# 4Geeks Academy         130.0                 8             3.0
# AcadGild                22.0                 2             1.0
# Academia de CÃ³digo     63.0                 4             4.0
# Academic Work Academy    0.0                 1             0.0
#
#                        BootcampFullJobAfter  BootcampLoanYesNo  \
# BootcampName
# 10x.org.il                              2.0                3.0
# 4Geeks Academy                          3.0                1.0
# AcadGild                                1.0                1.0
# Academia de CÃ³digo                     3.0                2.0
# Academic Work Academy                   0.0                1.0
#
#                        BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# BootcampName
# 10x.org.il                       200000.0                3.0            11.0
# ...

# %%
# extract only BootcampRecommend out
recommender = groupby_name["BootcampRecommend"]
total_rec = recommender.sum().head()

# %%
# convert SeriesGroupby to DataFrame
recommender_df = pd.DataFrame(total_rec)
recommender_df = recommender_df.reset_index()
recommender_df.rename(columns = {"BootcampRecommend":"Recommenders"})
recommender_df.head()
# Out:
#             BootcampName  BootcampRecommend
# 0             10x.org.il                3.0
# 1         4Geeks Academy                4.0
# 2               AcadGild                2.0
# 3    Academia de CÃ³digo                4.0
# 4  Academic Work Academy                0.0

# %%
# Merge the two created data frames on the name of tbe bootcamp
sub_merge = pd.merge(bc_name, recommender_df, on="BootcampName", how="right")
sub_merge.head()
# Out:
#             BootcampName  Count  BootcampRecommend
# 0         4Geeks Academy      8                4.0
# 1             10x.org.il      5                3.0
# 2    Academia de CÃ³digo      4                4.0
# 3               AcadGild      2                2.0
# 4  Academic Work Academy      1                0.0

# %%
# Calculate percentage of each bootcamp's students who are recommenders
sub_merge["%Recommend"] = (sub_merge["BootcampRecommend"] / sub_merge["Count"]) * 100
sub_merge.head()
# Out:
#             BootcampName  Count  BootcampRecommend  %Recommend
# 0         4Geeks Academy      8                4.0        50.0
# 1             10x.org.il      5                3.0        60.0
# 2    Academia de CÃ³digo      4                4.0       100.0
# 3               AcadGild      2                2.0       100.0
# 4  Academic Work Academy      1                0.0         0.0

# %%
# Think of what should be the numerator and the demoninator


# Sort results in descending order
sort_sub_merge = sub_merge.sort_values(["%Recommend"], ascending=False)


# Format for percentages
sort_sub_merge["%Recommend"] = sort_sub_merge["%Recommend"].map("{:,.2f}%".format)

sort_sub_merge.head()
# Out:
#             BootcampName  Count  BootcampRecommend %Recommend
# 2    Academia de CÃ³digo      4                4.0    100.00%
# 3               AcadGild      2                2.0    100.00%
# 1             10x.org.il      5                3.0     60.00%
# 0         4Geeks Academy      8                4.0     50.00%
# 4  Academic Work Academy      1                0.0      0.00%

# %%
# Export to excel and remove index
sort_sub_merge.to_excel("output/Bootcamppart2.xlsx", index=False)
